# %% [markdown]
# <center>
#     <img src="https://s3-api.us-geo.objectstorage.softlayer.net/cf-courses-data/CognitiveClass/Logos/organization_logo/organization_logo.png" width="300" alt="cognitiveclass.ai logo"  />
# </center>

# %% [markdown]
# #### Add your code below following the instructions given in the course

# %% [markdown]
# # My Jupyter notebook on IBM Watson Studio

# %% [markdown]
# __Yahaya Haruna Yahaya__ <br>
# I am a professional surveyor

# %% [markdown]
# _I am intrested in data science because i want to be a Spatial data scientist._

# %% [markdown]
# ### the code will calculate the performance of a particular student among his peers in a given test. If the student score 70% and the class highest score is 90%.

# %%
X =(70/90)*100

# %%
print('student A is', X ,'percentile worthy among his peers' )
# Out:
# student A is 77.77777777777779 percentile worthy among his peers

# %% [markdown]
# | s/n | Heading | Heading | Heading |
# | ---- | ---- | ---- | ---- |
# | 1 | Word | Word | Word |
# | 2 | Word | Word | Word |
